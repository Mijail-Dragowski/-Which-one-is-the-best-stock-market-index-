# %% [markdown]
# # <center>¿Wich one is the best stock market index?</center>
#
# ### **<center>A market study of the main stock  indexes in the world  </center>**
#
# ### **<center>Mijail Dragowski</center>**
# ### **<center>2023</center>**

# %% [markdown]
# ## Import the necesary librarys

# %%
import yfinance as yf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## load the Stocks index data

# %%
SP500 = yf.download("^GSPC", start="2002-01-01", end="2022-12-31")
SP500.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2002-01-02  1148.079956  1154.670044  1136.229980  1154.670044  1154.670044
# 2002-01-03  1154.670044  1165.270020  1154.010010  1165.270020  1165.270020
# 2002-01-04  1165.270020  1176.550049  1163.420044  1172.510010  1172.510010
# 2002-01-07  1172.510010  1176.969971  1163.550049  1164.890015  1164.890015
# 2002-01-08  1164.890015  1167.599976  1157.459961  1160.709961  1160.709961
#
#                 Volume
# Date
# 2002-01-02  1171000000
# 2002-01-03  1398900000
# 2002-01-04  1513000000
# 2002-01-07  1308300000
# 2002-01-08  1258800000

# %%
Nasdaq = yf.download("^IXIC", start="2002-01-01", end="2022-12-31")
Nasdaq.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2002-01-02  1965.180054  1979.260010  1936.560059  1979.250000  1979.250000
# 2002-01-03  1987.060059  2044.560059  1987.060059  2044.270020  2044.270020
# 2002-01-04  2061.830078  2077.889893  2033.560059  2059.379883  2059.379883
# 2002-01-07  2075.239990  2081.090088  2036.859985  2037.099976  2037.099976
# 2002-01-08  2039.420044  2060.229980  2027.339966  2055.739990  2055.739990
#
#                 Volume
# Date
# 2002-01-02  1517670000
# 2002-01-03  2209630000
# 2002-01-04  2205610000
# 2002-01-07  2121110000
# 2002-01-08  1873670000

# %%
DowJones = yf.download("^DJI", start="2002-01-01", end="2022-12-31")
DowJones.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2002-01-02  10021.709961  10074.019531   9935.700195  10073.400391
# 2002-01-03  10073.879883  10174.009766  10051.950195  10172.139648
# 2002-01-04  10176.839844  10283.669922  10174.839844  10259.740234
# 2002-01-07  10261.330078  10300.150391  10188.120117  10197.049805
# 2002-01-08  10195.759766  10211.230469  10121.349609  10150.549805
#
#                Adj Close     Volume
# Date
# 2002-01-02  10073.400391  203990000
# 2002-01-03  10172.139648  275020000
# 2002-01-04  10259.740234  239480000
# 2002-01-07  10197.049805  225880000
# 2002-01-08  10150.549805  193640000

# %%
FTSE = yf.download("^FTSE", start="2002-01-01", end="2022-12-31")
FTSE.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2002-01-02  5217.399902  5261.899902  5195.200195  5218.299805  5218.299805
# 2002-01-03  5218.299805  5328.399902  5218.299805  5318.799805  5318.799805
# 2002-01-04  5318.799805  5362.299805  5313.899902  5323.799805  5323.799805
# 2002-01-07  5323.799805  5354.200195  5277.700195  5293.600098  5293.600098
# 2002-01-08  5293.600098  5307.299805  5238.700195  5250.399902  5250.399902
#
#                 Volume
# Date
# 2002-01-02   630830000
# 2002-01-03   928236000
# 2002-01-04  1097681000
# 2002-01-07   900070000
# 2002-01-08  1495695000

# %%
DAX = yf.download("^GDAXI", start="2002-01-01", end="2022-12-31")
DAX.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2002
head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  Volume
# Date
# 2002-01-02  698.000000  725.059998  690.359985  724.950012  724.950012  618700
# 2002-01-03  726.760010  735.770020  722.349976  727.659973  727.659973  752600
# 2002-01-04  744.460022  750.830017  739.140015  747.719971  747.719971  630700
# 2002-01-07  748.539978  757.809998  735.549988  751.479980  751.479980  753600
# 2002-01-08  747.210022  750.890015  734.760010  734.760010  734.760010  799300

# %%
HANG_SENG = yf.download("^HSI", start="2002-01-01", end="2022-12-31")
HANG_SENG.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2002-01-02  11368.129883  11368.129883  11241.629883  11350.849609
# 2002-01-03  11348.799805  11447.000000  11348.799805  11423.519531
# 2002-01-04  11547.009766  11727.809570  11547.009766  11702.150391
# 2002-01-07  11687.429688  11905.549805  11687.429688  11892.639648
# 2002-01-08  11781.190430  11806.250000  11678.059570  11713.709961
#
#                Adj Close     Volume
# Date
# 2002-01-02  11350.849609  106074600
# 2002-01-03  11423.519531  274626200
# 2002-01-04  11702.150391  362553600
# 2002-01-07  11892.639648  442387000
# 2002-01-08  11713.709961  279504600

# %% [markdown]
# ## Open price time series chart

# %%
SP500['Open'].plot(label='SP500',figsize=(16,8),title='Open Price')
Nasdaq['Open'].plot(label='NASDAQ')
DowJones['Open'].plot(label='DowJones')
FTSE['Open'].plot(label='FTSE')
DAX['Open'].plot(label='DAX')
Nikkei['Open'].plot(label='Nikkei 225')
CAC['Open'].plot(label='CAC 40')
Euro_zone['Open'].plot(label="Euro_zone")
RUSSIA['Open'].plot(label="RUSSIA")
HANG_SENG['Open'].plot(label="HANG_SENG")
Kospi['Open'].plot(label="Kospi")

plt.legend()

# %% [markdown]
# # Return

# %% [markdown]
# ### Daily return calculation

# %%
SP500["daily return"]=SP500["Adj Close"].pct_change(1)
Nasdaq["daily return"]=Nasdaq["Adj Close"].pct_change(1)
DowJones["daily return"]=DowJones["Adj Close"].pct_change(1)
FTSE["daily return"]=FTSE["Adj Close"].pct_change(1)
DAX["daily return"]=DAX["Adj Close"].pct_change(1)
Nikkei["daily return"]=Nikkei["Adj Close"].pct_change(1)
CAC["daily return"]=CAC["Adj Close"].pct_change(1)
Euro_zone["daily return"]=Euro_zone["Adj Close"].pct_change(1)
RUSSIA["daily return"]=RUSSIA["Adj Close"].pct_change(1)
Kospi["daily return"]=Kospi["Adj Close"].pct_change(1)
HANG_SENG["daily return"]=HANG_SENG["Adj Close"].pct_change(1)

# %% [markdown]
# ### Accumulated daily return calculation

# %%
SP500['Cumulative Return'] = (1 + SP500['daily return']).cumprod()
Nasdaq['Cumulative Return'] = (1 + Nasdaq['daily return']).cumprod()
DowJones['Cumulative Return'] = (1 + DowJones['daily return']).cumprod()
FTSE['Cumulative Return'] = (1 + FTSE['daily return']).cumprod()
DAX['Cumulative Return'] = (1 + DAX['daily return']).cumprod()
Nikkei['Cumulative Return'] = (1 + Nikkei['daily return']).cumprod()
CAC['Cumulative Return'] = (1 + CAC['daily return']).cumprod()
Euro_zone['Cumulative Return'] = (1 + Euro_zone['daily return']).cumprod()
RUSSIA['Cumulative Return'] = (1 + RUSSIA['daily return']).cumprod()
Kospi['Cumulative Return'] = (1 + Kospi['daily return']).cumprod()
HANG_SENG['Cumulative Return'] = (1 + HANG_SENG['daily return']).cumprod()

# %% [markdown]
# ### Accumulated daily return time series chart

# %%
SP500['Cumulative Return'].plot(label='SP500',figsize=(16,8),title='Cumulative Return')
Nasdaq['Cumulative Return'].plot(label='Nasdaq')
DowJones['Cumulative Return'].plot(label='Dow Jones')
FTSE['Cumulative Return'].plot(label='FTSE')
DAX['Cumulative Return'].plot(label='DAX')
Nikkei['Cumulative Return'].plot(label='Nikkei 225')
CAC['Cumulative Return'].plot(label='CAC 40')
Euro_zone['Cumulative Return'].plot(label='Euro zone')
RUSSIA['Cumulative Return'].plot(label='Russia')
Kospi['Cumulative Return'].plot(label='Kospi')
HANG_SENG['Cumulative Return'].plot(label='HANG_SENG')
plt.legend()

# %% [markdown]
# # Risk (volatility)

# %% [markdown]
# ### Adjusted closing price density chart

# %%
SP500['Adj Close'].plot(kind='kde',label='SP500',figsize=(12,6))
Nasdaq['Adj Close'].plot(kind='kde',label='Nasdaq')
DowJones['Adj Close'].plot(kind='kde',label='Dow Jones')
FTSE['Adj Close'].plot(kind='kde',label='FTSE')
DAX['Adj Close'].plot(kind='kde',label='Dax')
Nikkei['Adj Close'].plot(kind='kde',label='Nikkei 225')
CAC['Adj Close'].plot(kind='kde',label='CAC 40')
Euro_zone['Adj Close'].plot(kind='kde',label='Euro zone')
RUSSIA['Adj Close'].plot(kind='kde',label='Russia')
Kospi['Adj Close'].plot(kind='kde',label='Kospi')
HANG_SENG['Adj Close'].plot(kind='kde',label='HANG_SENG')

plt.legend()

# %% [markdown]
# ### Daily return density chart

# %%
SP500['daily return'].plot(kind='kde',label='SP500',figsize=(12,6))
Nasdaq['daily return'].plot(kind='kde',label='Nasdaq')
DowJones['daily return'].plot(kind='kde',label='Dow Jones')
FTSE['daily return'].plot(kind='kde',label='FTSE')
DAX['daily return'].plot(kind='kde',label='Dax')
Nikkei['daily return'].plot(kind='kde',label='Nikkei 225')
CAC['daily return'].plot(kind='kde',label='CAC 40')
Euro_zone['daily return'].plot(kind='kde',label='Euro zone')
RUSSIA['daily return'].plot(kind='kde',label='Russia')
Kospi['daily return'].plot(kind='kde',label='Kospi')
HANG_SENG['daily return'].plot(kind='kde',label='HANG_SENG')

plt.legend()

# %% [markdown]
# # Sharpe ratio

# %% [markdown]
# ### Annualized sharpe ratio calculation

# %%
ASR_SP500 = ((SP500['daily return'].mean()*252)-0.0498)/(SP500['daily return'].std()*252**0.5)
ASR_Nasdaq = ((Nasdaq['daily return'].mean()*252)-0.0498)/(Nasdaq['daily return'].std()*252**0.5)
ASR_DowJones = ((DowJones['daily return'].mean()*252)-0.0498)/(DowJones['daily return'].std()*252**0.5)
ASR_FTSE = ((FTSE['daily return'].mean()*252)-0.0498)/(FTSE['daily return'].std()*252**0.5)
ASR_DAX = ((DAX['daily return'].mean()*252)-0.0498)/(DAX['daily return'].std()*252**0.5)
ASR_Nikkei = ((Nikkei['daily return'].mean()*252)-0.0498)/(Nikkei['daily return'].std()*252**0.5)
ASR_CAC = ((CAC['daily return'].mean()*252)-0.0498)/(CAC['daily return'].std()*252**0.5)
ASR_Euro_zone = ((Euro_zone['daily return'].mean()*252)-0.0498)/(Euro_zone['daily return'].std()*252**0.5)
ASR_RUSSIA = ((RUSSIA['daily return'].mean()*252)-0.0498)/(RUSSIA['daily return'].std()*252**0.5)
ASR_Kospi = ((Kospi['daily return'].mean()*252)-0.0498)/(Kospi['daily return'].std()*252**0.5)
ASR_HANG_SENG = ((HANG_SENG['daily return'].mean()*252)-0.0498)/(HANG_SENG['daily return'].std()*252**0.5)

# %% [markdown]
# ### View of each  annualized sharpe ratio for all index

# %%
df=[ASR_SP500, ASR_Nasdaq, ASR_DowJones, ASR_FTSE, ASR_DAX, ASR_Nikkei, ASR_CAC, ASR_Euro_zone, ASR_RUSSIA,ASR_Kospi, ASR_HANG_SENG]
ASR= pd.DataFrame([df])  
ASR.columns=["ASR_SP500", "ASR_Nasdaq", "ASR_DowJones", "ASR_FTSE", "ASR_DAX", "ASR_Nikkei", "ASR_CAC"," ASR_Euro_zone", "ASR_RUSSIA","ASR_Kospi", "ASR_HANG_SENG"]

ASR
# Out:
#    ASR_SP500  ASR_Nasdaq  ASR_DowJones  ASR_FTSE   ASR_DAX  ASR_Nikkei  \
# 0    0.13656    0.244246      0.131063 -0.084727  0.102164    0.085182
#
#     ASR_CAC   ASR_Euro_zone  ASR_RUSSIA  ASR_Kospi  ASR_HANG_SENG
# 0 -0.038029        -0.03731    0.082366   0.128407       0.014389

# %% [markdown]
# ### Graph of each annualized sharpe ratio

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ASR.plot.bar(ax=ax,ec="black")

ax.set_title('annualized sharpe ratio')
ax.set_xlabel("Index")
ax.set_ylabel('ASR values')
ax.spines['right'].set_visible(False) 
ax.spines['top'].set_visible(False)  
ax.tick_params(axis='x', length=0) 
ax.grid(axis='y', linestyle='--', alpha=0.7)  
ax.legend(loc='upper right', frameon=False, bbox_to_anchor=(1.15, 1)) 
plt.xticks(rotation=0)  

colors = ['red', 'green', 'blue',"yellow", "pink", "grey","black","orange","purple","brown", "gold"]
for i, c in enumerate(ax.containers):
    
    ax.bar_label(c, label_type='center', fontsize=0, color='black')

ax.set_xticklabels([])
plt.tight_layout()
plt.show()
